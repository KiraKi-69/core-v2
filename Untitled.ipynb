# %%
import json

import requests

inference_request = {
  "parameters": {
    "content_type": "pd"
  },
  "inputs": [
    {
      "name": "zipcode",
      "datatype": "INT32",
      "shape": [1],
      "data": [35544]
    },
    {
      "name": "dob_ssn",
      "datatype": "BYTES",
      "parameters": {
        "content_type": "str"
      },
      "shape": [1],
      "data": ["19460120_6984"]
    },
    {
      "name": "person_age",
      "datatype": "INT32",
      "shape": [1],
      "data": [53]
    },
    {
      "name": "person_home_ownership",
      "datatype": "BYTES",
      "parameters": {
        "content_type": "str"
      },
      "shape": [1],
      "data": ["MORTGAGE"]
    },
    {
      "name": "person_emp_length",
      "datatype": "FP32",
      "shape": [1],
      "data": [4.0]
    },
    {
      "name": "loan_intent",
      "datatype": "BYTES",
      "parameters": {
        "content_type": "str"
      },
      "shape": [1],
      "data": ["PERSONAL"]
    },
    {
      "name": "loan_amnt",
      "datatype": "INT32",
      "shape": [1],
      "data": [10000]
    },
    {
      "name": "loan_int_rate",
      "datatype": "FP32",
      "shape": [1],
      "data": [8.94]
    },
  ]
}

endpoint = "http://seldon-mesh.seldon-mesh.svc.cluster.local/v2/models/prod-m/infer"
response = requests.post(endpoint, json=inference_request)

print(response)
print(json.dumps(response.json(), indent=2))
assert response.ok
# Out:
# <Response [500]>
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-1-ab9b445f78ad> in <module>
#      72
#      73 print(response)
# ---> 74 print(json.dumps(response.json(), indent=2))
#      75 assert response.ok
#
# /opt/conda/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# /opt/conda/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# /opt/conda/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /opt/conda/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
{
	"data": {
		"names": [
			"zipcode",
			"dob_ssn",
			"person_age",
			"person_home_ownership",
			"person_emp_length",
			"loan_intent",
			"loan_amnt",
			"loan_int_rate"
		],
		"tensor": {
			"shape": [
				8
			],
			"values": 
		}
	}
}

[35544, "19460120_6984", 53, "MORTGAGE", 4.0, "PERSONAL", 10000, 8.94]

# %%
import os

print(os.environ)
# Out:
# environ({'SHELL': '/bin/bash', 'KUBERNETES_SERVICE_PORT_HTTPS': '443', 'APP_COR_MLFLOW_MLFLOW_TRACKING_PORT_80_TCP': 'tcp://172.30.148.249:80', 'KUBERNETES_SERVICE_PORT': '443', 'KUBERNETES_AWS_SECRET_ACCESS_KEY': '4RcodJsDmyDRUHrZUZD9GCkFr6HcX8kVnVnhgAhq', 'PROJECT_NAME': 'cor', 'KUBERNETES_S3_BUCKET': 'app-cor', 'APP_COR_MLFLOW_MLFLOW_TRACKING_SERVICE_HOST': '172.30.148.249', 'HOSTNAME': 'core-0', 'LANGUAGE': 'en_US.UTF-8', 'APP_COR_MLFLOW_MLFLOW_TRACKING_SERVICE_PORT_HTTP': '80', 'KUBERNETES_AWS_ACCESS_KEY_ID': 'MVG161ZMP4AF6NWD9LRN', 'APP_COR_MLFLOW_POSTGRESQL_PORT': 'tcp://172.30.26.101:5432', 'NB_UID': '1000', 'CORE_SERVICE_PORT': '80', 'FEAST_S3_ENDPOINT_URL': 'https://s3-mlops.neoflex.ru', 'PWD': '/home/jovyan', 'NB_PREFIX': '/notebook/app-cor/core', 'MLFLOW_S3_ENDPOINT_URL': 'https://s3-mlops.neoflex.ru', 'HOME': '/home/jovyan', 'APP_REALM_NAME': 'app', 'MLFLOW_TRACKING_URI': 'http://app-cor-mlflow-mlflow-tracking', 'LANG': 'en_US.UTF-8', 'KUBERNETES_PORT_443_TCP': 'tcp://172.30.0.1:443', 'APP_COR_MLFLOW_MLFLOW_TRACKING_PORT_80_TCP_ADDR': '172.30.148.249', 'GIT_USER': 'sd45661', 'APP_COR_MLFLOW_POSTGRESQL_SERVICE_HOST': '172.30.26.101', 'KUBERNETES_APP_KEYCLOAK_URL': 'https://app.demo.ml.neoflex.ru/auth/', 'AWS_SECRET_ACCESS_KEY': '4RcodJsDmyDRUHrZUZD9GCkFr6HcX8kVnVnhgAhq', 'APP_COR_MLFLOW_MLFLOW_TRACKING_PORT': 'tcp://172.30.148.249:80', 'CORE_PORT_80_TCP_PORT': '80', 'WEBASSEM_IMAGE': 'registry.neomsa.ru/docker-mlops/mlops/webassembly:1.0.2', 'KUBERNETES_MLFLOW_TRACKING_URI': 'http://app-cor-mlflow-mlflow-tracking', 'APP_KEYCLOAK_URL': 'https://app.demo.ml.neoflex.ru/auth/', 'GIT_PASSWORD': 'd7gojgvv6rfk8GS56fncvSg6D', 'APP_COR_MLFLOW_MLFLOW_TRACKING_PORT_80_TCP_PORT': '80', 'KUBERNETES_MLFLOW_TRACKING_INSECURE_TLS': 'true', 'SHLVL': '0', 'CORE_PORT': 'tcp://172.30.39.149:80', 'CONDA_DIR': '/opt/conda', 'AWS_ACCESS_KEY_ID': 'MVG161ZMP4AF6NWD9LRN', 'KUBERNETES_PORT_443_TCP_PROTO': 'tcp', 'APP_COR_MLFLOW_MLFLOW_TRACKING_SERVICE_PORT': '80', 'APP_COR_MLFLOW_POSTGRESQL_SERVICE_PORT': '5432', 'KUBERNETES_PORT_443_TCP_ADDR': '172.30.0.1', 'KUBERNETES_FEAST_S3_ENDPOINT_URL': 'https://s3-mlops.neoflex.ru', 'KUBERNETES_GIT_PASSWORD': 'd7gojgvv6rfk8GS56fncvSg6D', 'APP_COR_MLFLOW_POSTGRESQL_SERVICE_PORT_TCP_POSTGRESQL': '5432', 'KUBERNETES_MLFLOW_S3_ENDPOINT_URL': 'https://s3-mlops.neoflex.ru', 'KUBERNETES_APP_REALM_NAME': 'app', 'APP_COR_MLFLOW_POSTGRESQL_PORT_5432_TCP_PORT': '5432', 'CORE_PORT_80_TCP': 'tcp://172.30.39.149:80', 'APP_COR_MLFLOW_MLFLOW_TRACKING_PORT_80_TCP_PROTO': 'tcp', 'APP_COR_MLFLOW_POSTGRESQL_PORT_5432_TCP_ADDR': '172.30.26.101', 'NB_USER': 'jovyan', 'KUBERNETES_SERVICE_HOST': '172.30.0.1', 'LC_ALL': 'en_US.UTF-8', 'KUBERNETES_PORT': 'tcp://172.30.0.1:443', 'KUBERNETES_PORT_443_TCP_PORT': '443', 'CORE_PORT_80_TCP_ADDR': '172.30.39.149', 'CWD': '/home/jovyan', 'CORE_SERVICE_HOST': '172.30.39.149', 'CORE_SERVICE_PORT_HTTP_CORE': '80', 'KUBERNETES_GIT_USER': 'sd45661', 'PATH': '/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'CORE_PORT_80_TCP_PROTO': 'tcp', 'APP_COR_MLFLOW_POSTGRESQL_PORT_5432_TCP_PROTO': 'tcp', 'FEAST_FS_YAML_FILE_PATH': '/vault/secrets/feature_store.yaml', 'S3_BUCKET': 'app-cor', 'MLFLOW_TRACKING_INSECURE_TLS': 'true', 'OLDPWD': '/run/s6/services/jupyterlab', 'APP_COR_MLFLOW_POSTGRESQL_PORT_5432_TCP': 'tcp://172.30.26.101:5432', 'GIT_PYTHON_REFRESH': 'quiet', 'JPY_PARENT_PID': '198', 'TERM': 'xterm-color', 'CLICOLOR': '1', 'PAGER': 'cat', 'GIT_PAGER': 'cat', 'MPLBACKEND': 'module://ipykernel.pylab.backend_inline'})

# %%
# %pip install mlflow==1.30
# %pip install boto3
# %pip install cloudpickle==2.2.1

# %%
import logging
import os
import requests
import json


class FeastRestEnricher(mlflow.pyfunc.PythonModel):
    
    def __init__(self):
        #FixME change to os.environ or param
        self.url = "http://feast-feature-server.feast-db:80/"
        
        
    def predict(self, context, X): ## X, features_names
        
        print(context)
        print(X)
        
        print("Enriching features: %s and values %s", X.columns, X.values)
        
        features_names = list(X.columns)
        
        zipcode = X['zipcode'].values[0]
        dob_ssn = X['dob_ssn'].values[0]

        print("Get data: zipcode %s and dob_ssn %s", zipcode, dob_ssn)
        
        req = {
            "feature_service": "loan_features",
            "entities": {
                "zipcode": int(zipcode),
                "dob_ssn": dob_ssn
            }
        }

        print("Send request to server: %s", json.dumps(req))
        
        response = requests.post(
            f"{self.url}get-online-features",
            data=json.dumps(req)
        )
        
        print(response)
        
        feature_vector = {}
        
        if response.status_code == 200:
            response_dict = response.json()
            print("response dict: %s", response_dict)
            for idx, column in enumerate(response_dict['metadata']['feature_names']):
                feature_vector[column] = response_dict['results'][idx]['values']
        
            for name in features_names:
                if feature_vector.get(name) is None:
                    print(X[name].values[0])
                    if name in ["loan_amnt", "person_age"]:
                        feature_vector[name] = int(X[name].values[0][0])
                    elif name in ["person_emp_length", "loan_int_rate"]:
                        feature_vector[name] = float(X[name].values[0][0])
                    else:
                        feature_vector[name] = X[name].values[0][0]
        
        print("result vector: %s", feature_vector)
        
        return feature_vector

# %%
import mlflow

mlflow.set_experiment("prepro")

with mlflow.start_run() as current_run:
    model_info = mlflow.pyfunc.log_model(
        artifact_path="model", 
        python_model=FeastRestEnricher()
        )

# %%
model_name = "model.bin"
encoder_name = "encoder.bin"

artifacts = {
    "model": model_name,
    "encoder": encoder_name,
}

class ModelWrapper(mlflow.pyfunc.PythonModel):

    def load_context(self, context):
        import joblib
        self.encoder = joblib.load(context.artifacts["encoder"])            
        self.model = joblib.load(context.artifacts["model"]) 
        self.categorical_features = [
            "person_home_ownership",
            "loan_intent",
            "state",
        ]

    def predict(self, context, inp):

        import pandas as pd
        
        print(context, inp)

        if isinstance(inp, dict):
            features_df = pd.DataFrame.from_dict(inp)
        elif isinstance(inp, pd.DataFrame):
            features_df = inp

        print("Enriching features DataFrame: %s", features_df)

        # Apply ordinal encoding to categorical features
        features_df[self.categorical_features] = self.encoder.transform(
            features_df[self.categorical_features]
        )

        print("features DataFrame after encoging: %s", features_df)

        # Sort columns
        features_df = features_df.reindex(sorted(features_df.columns), axis=1)

        # Drop unnecessary columns
        df_for_predict = features_df.copy()
        if "city" in df_for_predict.columns:
            df_for_predict = df_for_predict[df_for_predict.columns.drop("city").drop("location_type")]

        if "zipcode" in df_for_predict.columns:
            df_for_predict = df_for_predict[df_for_predict.columns.drop("zipcode").drop("dob_ssn")]

        print("features DataFrame before predict: %s", df_for_predict)
        
        result = self.model.predict(df_for_predict)

        return result

# %%
import mlflow

mlflow.set_experiment("mod")

with mlflow.start_run() as current_run:
    model_info = mlflow.pyfunc.log_model(
        artifact_path="model", 
        python_model=ModelWrapper(),
        artifacts=artifacts,
        )
