# %% [markdown]
# # Подготовка данных для обучения

# %%
import pandas as pd

data_path = 'credit_history_all.csv'

df = pd.read_csv(data_path)

# %%
del df['created_timestamp']
del df['event_timestamp']
del df['loan_id']
del df['zipcode']
del df['dob_ssn']

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          52          69996                   OWN                3.0
# 1          61          10636                  RENT                3.0
# 2          36          69000                  RENT                0.0
# 3          36          48686                  RENT               21.0
# 4          36          44000                  RENT                4.0
#
#          loan_intent  loan_amnt  loan_int_rate  loan_status        city state  \
# 0           PERSONAL      12000          11.11            0    CUMMINGS    KS
# 1           PERSONAL       4000          12.21            1     CRESSON    TX
# 2            MEDICAL      15600          10.99            0  PLAINVILLE    GA
# 3            MEDICAL      12000          13.99            0     CLINTON    NC
# 4  DEBTCONSOLIDATION       8000          17.49            1   NASHVILLE    TN
#
#    ... total_wages  credit_card_due  mortgage_due  student_loan_due  \
# 0  ...     9617849             7649        779433             28579
# 1  ...    38291019             5101       1877182             32008
# 2  ...    23478174             4223       1142978             24020
# 3  ...    35505191             6993        592528             40529
# 4  ...   571965786             1552       1786677             26664
#
#    vehicle_loan_due  hard_pulls  missed_payments_2y  missed_payments_1y  \
# 0              3583           0                   0                   0
# 1             20745           6                   1                   3
# 2             11711           3                   5                   1
# 3             17508           1                   1                   0
# 4             19749           8                   2                   0
#
#    missed_payments_6m  bankruptcies
# 0                   0             0
# 1                   0             0
# 2                   1             2
# 3                   0             0
# 4                   1             0
#
# [5 rows x 23 columns]

# %% [markdown]
# Для проверки в пайплайне с энкодером

# %%
X = df[df.columns.drop("loan_status")].copy()
y = df[["loan_status"]].copy()

# %%
columns = list(X.columns)
columns
# Out:
# ['person_age',
#  'person_income',
#  'person_home_ownership',
#  'person_emp_length',
#  'loan_intent',
#  'loan_amnt',
#  'loan_int_rate',
#  'city',
#  'state',
#  'location_type',
#  'tax_returns_filed',
#  'population',
#  'total_wages',
#  'credit_card_due',
#  'mortgage_due',
#  'student_loan_due',
#  'vehicle_loan_due',
#  'hard_pulls',
#  'missed_payments_2y',
#  'missed_payments_1y',
#  'missed_payments_6m',
#  'bankruptcies']

# %%
X = X.values
X
# Out:
# array([[52, 69996, 'OWN', ..., 0, 0, 0],
#        [61, 10636, 'RENT', ..., 3, 0, 0],
#        [36, 69000, 'RENT', ..., 1, 1, 2],
#        ...,
#        [24, 200000, 'MORTGAGE', ..., 0, 0, 0],
#        [23, 74000, 'RENT', ..., 1, 0, 0],
#        [23, 12996, 'OWN', ..., 0, 0, 2]], dtype=object)

# %%
y = y.values
y
# Out:
# array([[0],
#        [1],
#        [0],
#        ...,
#        [0],
#        [1],
#        [1]])

# %%
len(y)
# Out:
# 28638

# %% [markdown]
# # Инициализируем модели

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import OrdinalEncoder

class DTCModel(object):  
    
    def __init__(self):
        
        self.categorical_features = [
            "person_home_ownership",
            "loan_intent",
            "city",
            "state",
            "location_type",
        ]
        
        self.encoder = joblib.load("encoder.pkl")
        
        print("Encoder loaded")
        
        self.model = joblib.load("DTC.pkl")
        
        print("Model loaded")
        
        self.cm = {"tp": 0, "fp": 0, "tn": 0, "fn": 0}

        self.tries = 0
        self.success = 0
        self.value = 0
        

    def predict(self,X,features_names):

        df = pd.DataFrame(X, columns=features_names)
        
        df[self.categorical_features] = self.encoder.transform(df[self.categorical_features])
        df = df.reindex(sorted(df.columns), axis=1)
        
        predictions = self.model.predict(df)
        
        return predictions

    def send_feedback(self, features, feature_names, reward, truth, routing=None):
        print("DTC model send-feedback entered")
        print(f"Truth: {truth}, Reward: {reward}")

        if reward == 1:
            if truth == 1:
                self.cm["tp"] += 1
            if truth == 0:
                self.cm["tn"] += 1
        if reward == 0:
            if truth == 1:
                self.cm["fn"] += 1
            if truth == 0:
                self.cm["fp"] += 1

        self.tries += 1
        self.success = self.success + 1 if reward else self.success
        self.value = self.success / self.tries

        print(self.cm)
        print(
            "Tries: %s, successes: %s, values: %s", self.tries, self.success, self.value
        )

    def metrics(self):
        tp = {
            "type": "GAUGE",
            "key": "true_pos_total",
            "value": self.cm["tp"],
            "tags": {"branch_name": "DTC"},
        }
        tn = {
            "type": "GAUGE",
            "key": "true_neg_total",
            "value": self.cm["tn"],
            "tags": {"branch_name": "DTC"},
        }
        fp = {
            "type": "GAUGE",
            "key": "false_pos_total",
            "value": self.cm["fp"],
            "tags": {"branch_name": "DTC"},
        }
        fn = {
            "type": "GAUGE",
            "key": "false_neg_total",
            "value": self.cm["fn"],
            "tags": {"branch_name": "DTC"},
        }

        value = {
            "type": "GAUGE",
            "key": "branch_value",
            "value": self.value,
            "tags": {"branch_name": "DTC"},
        }
        success = {
            "type": "GAUGE",
            "key": "n_success_total",
            "value": self.success,
            "tags": {"branch_name": "DTC"},
        }
        tries = {
            "type": "GAUGE",
            "key": "n_tries_total",
            "value": self.tries,
            "tags": {"branch_name": "DTC"},
        }

        return [tp, tn, fp, fn, value, success, tries]

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import OrdinalEncoder

class GBCModel(object):  
    
    def __init__(self):
        
        self.categorical_features = [
            "person_home_ownership",
            "loan_intent",
            "city",
            "state",
            "location_type",
        ]
        
        self.encoder = joblib.load("encoder.pkl")
        
        print("Encoder loaded")
        
        self.model = joblib.load("GBC.pkl")
        
        print("Model loaded")
        
        self.cm = {"tp": 0, "fp": 0, "tn": 0, "fn": 0}

        self.tries = 0
        self.success = 0
        self.value = 0

    def predict(self,X,features_names):

        df = pd.DataFrame(X, columns=features_names)
        
        df[self.categorical_features] = self.encoder.transform(df[self.categorical_features])
        df = df.reindex(sorted(df.columns), axis=1)
        
        predictions = self.model.predict(df)
        
        print(predictions)
        
        return predictions

    def send_feedback(self, features, feature_names, reward, truth, routing=None):
        print("GBC model send-feedback entered")
        print(f"Truth: {truth}, Reward: {reward}")

        if reward == 1:
            if truth == 1:
                self.cm["tp"] += 1
            if truth == 0:
                self.cm["tn"] += 1
        if reward == 0:
            if truth == 1:
                self.cm["fn"] += 1
            if truth == 0:
                self.cm["fp"] += 1

        self.tries += 1
        self.success = self.success + 1 if reward else self.success
        self.value = self.success / self.tries

        print(self.cm)
        print(
            "Tries: %s, successes: %s, values: %s", self.tries, self.success, self.value
        )

    def metrics(self):
        tp = {
            "type": "GAUGE",
            "key": "true_pos_total",
            "value": self.cm["tp"],
            "tags": {"branch_name": "GBC"},
        }
        tn = {
            "type": "GAUGE",
            "key": "true_neg_total",
            "value": self.cm["tn"],
            "tags": {"branch_name": "GBC"},
        }
        fp = {
            "type": "GAUGE",
            "key": "false_pos_total",
            "value": self.cm["fp"],
            "tags": {"branch_name": "GBC"},
        }
        fn = {
            "type": "GAUGE",
            "key": "false_neg_total",
            "value": self.cm["fn"],
            "tags": {"branch_name": "GBC"},
        }

        value = {
            "type": "GAUGE",
            "key": "branch_value",
            "value": self.value,
            "tags": {"branch_name": "GBC"},
        }
        success = {
            "type": "GAUGE",
            "key": "n_success_total",
            "value": self.success,
            "tags": {"branch_name": "GBC"},
        }
        tries = {
            "type": "GAUGE",
            "key": "n_tries_total",
            "value": self.tries,
            "tags": {"branch_name": "GBC"},
        }

        return [tp, tn, fp, fn, value, success, tries]

# %% [markdown]
# # Цикл тестирования

# %%
import joblib

dtc = DTCModel()
gbc = GBCModel()
# Out:
# Encoder loaded
# Model loaded
# Encoder loaded
# Model loaded

# %%
import numpy as np
import requests

n = 100

for i in range(n):
    print(f"Processed {i+1}/{n} samples", flush=True)  
    
#     Локальный тест классов !!!!!!!!!!

#     print([X[i].tolist()])
#     pred = dtc.predict([X[i].tolist()], columns)
#     print(pred)
    
#     truth_val = int(y[i][0])
    
#     reward = int(pred == truth_val)
#     print(reward)
    
#     _ = dtc.send_feedback([], [], reward, truth_val)
    
#     reward = int(pred == truth_val)


#     Тест на сервере !!!!!!!!!!
    port = "36991"
    url = "http://test-ab-default.seldon-mesh.svc.cluster.local:8000/api/v1.0/predictions" # Надо заполнить
    url_feedback = "http://test-ab-default.seldon-mesh.svc.cluster.local:8000/api/v1.0/feedback"
    req = {"data": {"ndarray": [X[i].tolist()], "names": columns}}
    
    res_raw = requests.post(
        url, json=req
    )
    res = res_raw.json()
    print("Respones: ", res)
    pred = res.get("data").get("ndarray")[0]
    
    truth_val = int(y[i][0])
    
    reward = int(pred == truth_val)
    
    truth = [truth_val]
    
    feedback = {
        "request": req,
        "response": res,
        "reward": reward,
        "truth": {"data": {"ndarray": truth}}
    }
    res_raw = requests.post(
        url_feedback, json=feedback
    )
    print(res_raw)
    assert res_raw.status_code == 200
# Out:
# Processed 1/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 79}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 21}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 100}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 2/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.05782128221009364, 0.9421787177899064]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 80}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 21}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 101}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 3/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.8007057788657951, 0.1992942211342049]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 80}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 22}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 102}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 4/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.8275802204256415, 0.17241977957435853]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 81}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 22}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 103}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 5/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.0, 1.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 82}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 22}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 104}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 6/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.7646012728274563, 0.2353987271725437]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 82}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 23}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 105}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 7/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9706357916545163, 0.029364208345483717]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 83}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 23}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 106}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 8/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 84}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 23}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 107}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 9/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 85}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 23}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 108}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 10/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9135233520789775, 0.08647664792102251]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 86}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 23}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 109}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 11/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 87}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 23}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 110}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 12/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 88}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 23}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 111}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 13/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 89}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 23}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 112}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 14/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 90}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 23}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 113}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 15/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9871571025950392, 0.01284289740496081]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 91}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 23}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 114}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 16/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 92}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 23}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 115}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 17/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.507671535891611, 0.49232846410838904]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 93}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 23}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 116}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 18/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 93}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 24}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 117}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 19/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.6797466854234209, 0.3202533145765792]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 94}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 24}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 118}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 20/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9740146770719362, 0.025985322928063808]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 95}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 24}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 119}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 21/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 96}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 24}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 120}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 22/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9579812745249251, 0.042018725475074875]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 97}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 24}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 121}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 23/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9867284881794164, 0.013271511820583635]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 98}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 24}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 122}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 24/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 99}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 24}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 123}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 25/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9844465459937223, 0.01555345400627773]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 100}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 24}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 124}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 26/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.976042856805833, 0.023957143194166995]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 101}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 24}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 125}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 27/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.5026013726462562, 0.49739862735374385]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 102}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 24}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 126}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 28/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 102}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 25}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 127}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 29/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 103}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 25}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 128}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 30/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.02946374336548485, 0.9705362566345151]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 104}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 25}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 129}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 31/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.5396299906422164, 0.4603700093577836]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 104}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 26}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 130}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 32/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9189351357230257, 0.08106486427697435]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 105}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 26}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 131}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 33/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 106}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 26}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 132}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 34/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9872808869346472, 0.01271911306535274]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 107}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 26}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 133}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 35/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.0, 1.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 108}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 26}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 134}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 36/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.07994773230541019, 0.9200522676945898]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 108}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 27}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 135}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 37/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 108}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 28}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 136}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 38/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 109}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 28}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 137}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 39/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.0, 1.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 110}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 28}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 138}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 40/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.6579681371469963, 0.3420318628530037]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 110}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 29}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 139}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 41/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.11571109206868835, 0.8842889079313117]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 111}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 29}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 140}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 42/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 111}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 30}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 141}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 43/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9929522800261549, 0.0070477199738451166]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 112}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 30}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 142}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 44/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.3376102969749524, 0.6623897030250476]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 113}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 30}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 143}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 45/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 113}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 31}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 144}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 46/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 114}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 31}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 145}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 47/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 115}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 31}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 146}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 48/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 116}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 31}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 147}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 49/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.0, 1.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 117}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 31}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 148}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 50/100 samples
# ...
# <Response [200]>
# Processed 85/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9753419773250684, 0.02465802267493158]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 145}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 39}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 184}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 86/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9683619045260882, 0.031638095473911824]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 146}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 39}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 185}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 87/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9705145098492834, 0.029485490150716515]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 147}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 39}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 186}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 88/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9826051623850962, 0.017394837614903777]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 148}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 39}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 187}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 89/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 149}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 39}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 188}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 90/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.0, 1.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 150}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 39}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 189}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 91/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9980879541108987, 0.0019120458891013384]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 150}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 40}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 190}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 92/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9422191484304304, 0.057780851569569545]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 151}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 40}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 191}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 93/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.7862547018625303, 0.21374529813746973]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 152}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 40}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 192}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 94/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9715330143826455, 0.02846698561735454]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 153}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 40}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 193}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 95/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 154}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 40}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 194}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 96/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.9633411481327254, 0.03665885186727462]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 155}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 40}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 195}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 97/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.3670634766534928, 0.6329365233465072]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 156}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 40}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 196}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 98/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.28080433586156905, 0.719195664138431]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 156}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 41}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 197}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 99/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[0.8373598762644392, 0.16264012373556086]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 156}, {'key': 'false_neg_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 42}, {'key': 'branch_value', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'GBC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 198}], 'requestPath': {'gbc-model': 'blcox/gbc-model-ab:v1.0'}}}
# <Response [200]>
# Processed 100/100 samples
# Respones:  {'data': {'names': ['t:0', 't:1'], 'ndarray': [[1.0, 0.0]]}, 'meta': {'metrics': [{'key': 'true_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'true_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'false_pos_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 157}, {'key': 'false_neg_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 42}, {'key': 'branch_value', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0.0}, {'key': 'n_success_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 0}, {'key': 'n_tries_total', 'tags': {'branch_name': 'DTC', 'method': 'predict'}, 'type': 'GAUGE', 'value': 199}], 'requestPath': {'dtc-model': 'blcox/dtc-model-ab:v1.0'}}}
# <Response [200]>

# %%
type([])
# Out:
# list
